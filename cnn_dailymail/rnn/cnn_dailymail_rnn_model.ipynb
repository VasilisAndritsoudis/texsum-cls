# %%
from transformers import BertTokenizerFast, BertModel
from transformers import AdamW
from tqdm.auto import tqdm

import torch
from torch.utils.data import DataLoader

from sklearn.metrics import f1_score, accuracy_score

import pandas as pd
import os

import warnings
warnings.filterwarnings('ignore')

print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ## Dataset Parameters

# %%
train_docs = 287113
val_docs = 13368
test_docs = 11490

num_neg_ex = 1

docs_per = 0.01

train_docs_used = int(2 * num_neg_ex * train_docs * docs_per)
val_docs_used = int(2 * num_neg_ex * val_docs * docs_per)
test_docs_used = int(2 * num_neg_ex * test_docs * docs_per)

print(f"Number of training documents used:{train_docs_used}")
print(f"Number of validation documents used:{val_docs_used}")
print(f"Number of testing documents used:{test_docs_used}")

data_path = 'processed_data'
# Out:
# Number of training documents used:5742
# Number of validation documents used:267
# Number of testing documents used:229

# %% [markdown]
# ## Model Hyperparameters

# %%
num_of_epochs = 1000
learning_rate = 1e-5
batch_size = 32
hidden_layers = 84

# %% [markdown]
# ## Loading Dataset
# Because of the large size of the Dataset, only a small portion of the documents will be loaded for training and validation.
#
# The labels are converted from 0, 1 to [1, 0] and [0, 1] respectively.

# %%
train_df = pd.read_csv(f"{data_path}/train.csv")
train_docs = train_df['input'][:train_docs_used].to_list()
train_y = train_df['label'][:train_docs_used].apply(lambda label: [0, 1] if label == 1 else [1, 0]).to_list()

val_df = pd.read_csv(f"{data_path}/validation.csv")
val_docs = val_df['input'][:val_docs_used].to_list()
val_y = val_df['label'][:val_docs_used].apply(lambda label: [0, 1] if label == 1 else [1, 0]).to_list()

# %% [markdown]
# ### Tokenization
# Each document is run through the tokenizer.

# %%
pretrained_model = "bert-base-uncased"
tokenizer = BertTokenizerFast.from_pretrained(pretrained_model)

# Tokenize train data
train_X = tokenizer(train_docs, max_length=512, truncation='longest_first', return_tensors="pt", padding="max_length")
val_X = tokenizer(val_docs, max_length=512, truncation='longest_first', return_tensors="pt", padding="max_length")

# %% [markdown]
# ### Custom PyTorch Dataset
# Create a custom PyTorch Dataset that will contain the tokenized text encodings. Then use DataLoaders to prepare the Dataset for training and testing.

# %%
class CnnDailymailDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        # an encoding can have keys such as input_ids and attention_mask
        # item is a dictionary which has the same keys as the encoding has
        # and the values are the idxth value of the corresponding key (in PyTorch's tensor format)
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataset = CnnDailymailDataset(train_X, train_y)
val_dataset = CnnDailymailDataset(val_X, val_y)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Model Setup

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

in_features = 512
hid_size = 128

class TexSumClassifier(torch.nn.Module):
    def __init__(self, linear_size):
        super(TexSumClassifier, self).__init__()
        self.rnn = torch.nn.LSTM(input_size=in_features, num_layers=2, hidden_size=hid_size, bidirectional=True)
        self.dropout1 = torch.nn.Dropout()
        self.linear1 = torch.nn.Linear(in_features=2*hid_size, out_features=linear_size)
        self.batch_norm1 = torch.nn.BatchNorm1d(num_features=linear_size)
        self.dropout2 = torch.nn.Dropout(p=0.8)
        self.linear2 = torch.nn.Linear(in_features=linear_size, out_features=2)
        self.batch_norm2 = torch.nn.BatchNorm1d(num_features=2)
        self.sigmoid = torch.nn.Sigmoid()
        self.softmax = torch.nn.Softmax(dim=1)

    def forward(self, tokens, attention_mask):
        rnn_output = self.rnn(tokens.float())
        x = self.dropout1(rnn_output[0].reshape(-1, 2*hid_size))
        x = self.linear1(x)
        x = self.batch_norm1(x)
        x = self.dropout2(x)
        x = self.linear2(x)
        x = self.batch_norm2(x)
        return self.softmax(x)

# %% [markdown]
# ### Metrics

# %%
def eval_prediction(y_batch_actual, y_batch_predicted):
    """Return batches of accuracy and f1 scores."""
    y_batch_actual_np = torch.argmax(y_batch_actual, dim=1).cpu().detach().numpy()
    y_batch_predicted_np = torch.argmax(y_batch_predicted, dim=1).cpu().detach().numpy()

    acc = accuracy_score(y_true=y_batch_actual_np, y_pred=y_batch_predicted_np)
    f1 = f1_score(y_true=y_batch_actual_np, y_pred=y_batch_predicted_np, average='weighted')

    return acc, f1

# %% [markdown]
# ### Model Initialization

# %%
model = TexSumClassifier(linear_size=hidden_layers)
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
loss_fn = torch.nn.BCELoss()

# %% [markdown]
# ### Training step

# %%
def training_step(dataloader, model, optimizer, loss_fn):
    """Method to train the model"""

    model.train()

    epoch_loss = 0

    for i, batch in enumerate(dataloader):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        
        optimizer.zero_grad()
        # outputs = torch.flatten(model(tokens=input_ids, attention_mask=attention_mask))
        outputs = model(tokens=input_ids, attention_mask=attention_mask)
        loss = loss_fn(outputs, labels.float())
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()

    return epoch_loss/i

# %% [markdown]
# ### Validation step

# %%
def validation_step(dataloader, model):
    """Method to test the model's accuracy and loss on the validation set"""

    model.eval()

    size = len(dataloader)
    f1, acc = 0, 0

    with torch.no_grad():
        for batch in dataloader:
            X = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            y = batch['labels'].to(device)

            pred = model(tokens=X, attention_mask=attention_mask)

            acc_batch, f1_batch = eval_prediction(y.float(), pred)
            acc += acc_batch
            f1 += f1_batch

        acc = acc/size
        f1 = f1/size

    return acc, f1

# %% [markdown]
# ## Training the Model

# %%
tqdm.pandas()

best_acc = 0
path = "./best_model.pt"
os.makedirs(os.path.dirname(path), exist_ok=True)

for i in tqdm(range(num_of_epochs)):
    epoch_loss = training_step(train_loader, model,optimizer, loss_fn)
    
    if (i+1) % 10 == 0 or i == 0: 
        # Print accuracy and F1 statistics every 10 epochs
        train_acc, train_f1 = validation_step(train_loader, model)
        val_acc, val_f1 = validation_step(val_loader, model)
        
        print("Training results: ")
        print("Acc: {:.3f}, f1: {:.3f}, loss: {:.3f}".format(train_acc, train_f1, epoch_loss))
        
        print("Validation results: ")
        print("Acc: {:.3f}, f1: {:.3f}".format(val_acc, val_f1))
        
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model, path)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Training results:
# Acc: 0.499, f1: 0.480, loss: 0.874
# Validation results:
# Acc: 0.488, f1: 0.488
# Training results:
# Acc: 0.497, f1: 0.483, loss: 0.855
# Validation results:
# Acc: 0.457, f1: 0.427
# Training results:
# Acc: 0.502, f1: 0.490, loss: 0.816
# Validation results:
# Acc: 0.519, f1: 0.513
# Training results:
# Acc: 0.502, f1: 0.471, loss: 0.787
# Validation results:
# Acc: 0.515, f1: 0.497
# Training results:
# Acc: 0.500, f1: 0.491, loss: 0.753
# Validation results:
# Acc: 0.474, f1: 0.446
# Training results:
# Acc: 0.505, f1: 0.495, loss: 0.741
# Validation results:
# Acc: 0.515, f1: 0.505
# Training results:
# Acc: 0.502, f1: 0.489, loss: 0.725
# Validation results:
# Acc: 0.426, f1: 0.424
# Training results:
# Acc: 0.506, f1: 0.498, loss: 0.719
# Validation results:
# Acc: 0.523, f1: 0.517
# Training results:
# Acc: 0.511, f1: 0.479, loss: 0.708
# Validation results:
# Acc: 0.485, f1: 0.437
# Training results:
# Acc: 0.497, f1: 0.435, loss: 0.704
# Validation results:
# Acc: 0.509, f1: 0.474
# Training results:
# Acc: 0.490, f1: 0.478, loss: 0.709
# Validation results:
# Acc: 0.488, f1: 0.464
# Training results:
# Acc: 0.510, f1: 0.489, loss: 0.703
# Validation results:
# Acc: 0.526, f1: 0.511
# Training results:
# Acc: 0.512, f1: 0.483, loss: 0.702
# Validation results:
# Acc: 0.526, f1: 0.494
# Training results:
# Acc: 0.509, f1: 0.501, loss: 0.702
# Validation results:
# Acc: 0.515, f1: 0.487
# Training results:
# Acc: 0.511, f1: 0.492, loss: 0.701
# Validation results:
# Acc: 0.509, f1: 0.491
# Training results:
# Acc: 0.504, f1: 0.462, loss: 0.698
# Validation results:
# Acc: 0.457, f1: 0.419
# Training results:
# Acc: 0.515, f1: 0.506, loss: 0.700
# Validation results:
# Acc: 0.467, f1: 0.443
# Training results:
# Acc: 0.502, f1: 0.492, loss: 0.699
# Validation results:
# Acc: 0.508, f1: 0.498
# Training results:
# Acc: 0.503, f1: 0.421, loss: 0.698
# Validation results:
# Acc: 0.513, f1: 0.421
# Training results:
# Acc: 0.497, f1: 0.475, loss: 0.699
# Validation results:
# Acc: 0.539, f1: 0.530
# Training results:
# Acc: 0.515, f1: 0.483, loss: 0.699
# Validation results:
# Acc: 0.509, f1: 0.482
# Training results:
# Acc: 0.507, f1: 0.494, loss: 0.698
# Validation results:
# Acc: 0.532, f1: 0.518
# Training results:
# Acc: 0.503, f1: 0.495, loss: 0.699
# Validation results:
# Acc: 0.571, f1: 0.563
# Training results:
# Acc: 0.505, f1: 0.486, loss: 0.698
# Validation results:
# Acc: 0.526, f1: 0.522
# Training results:
# Acc: 0.499, f1: 0.488, loss: 0.699
# Validation results:
# Acc: 0.498, f1: 0.474
# Training results:
# Acc: 0.504, f1: 0.491, loss: 0.698
# Validation results:
# Acc: 0.498, f1: 0.479
# Training results:
# Acc: 0.507, f1: 0.495, loss: 0.697
# Validation results:
# Acc: 0.474, f1: 0.453
# Training results:
# Acc: 0.508, f1: 0.459, loss: 0.697
# Validation results:
# Acc: 0.498, f1: 0.445
# Training results:
# Acc: 0.502, f1: 0.487, loss: 0.698
# Validation results:
# Acc: 0.512, f1: 0.496
# Training results:
# Acc: 0.510, f1: 0.492, loss: 0.698
# Validation results:
# Acc: 0.525, f1: 0.512
# Training results:
# Acc: 0.514, f1: 0.502, loss: 0.698
# Validation results:
# Acc: 0.512, f1: 0.492
# Training results:
# Acc: 0.511, f1: 0.498, loss: 0.697
# Validation results:
# Acc: 0.509, f1: 0.503
# Training results:
# Acc: 0.506, f1: 0.485, loss: 0.698
# Validation results:
# Acc: 0.471, f1: 0.448
# Training results:
# Acc: 0.505, f1: 0.471, loss: 0.698
# Validation results:
# Acc: 0.502, f1: 0.481
# Training results:
# Acc: 0.512, f1: 0.498, loss: 0.697
# Validation results:
# Acc: 0.509, f1: 0.481
# Training results:
# Acc: 0.519, f1: 0.506, loss: 0.698
# Validation results:
# Acc: 0.488, f1: 0.468
# Training results:
# Acc: 0.511, f1: 0.494, loss: 0.697
# Validation results:
# Acc: 0.491, f1: 0.476
# Training results:
# Acc: 0.522, f1: 0.499, loss: 0.698
# Validation results:
# Acc: 0.521, f1: 0.511
# Training results:
# Acc: 0.521, f1: 0.490, loss: 0.697
# Validation results:
# Acc: 0.450, f1: 0.433
# Training results:
# Acc: 0.512, f1: 0.462, loss: 0.698
# Validation results:
# Acc: 0.526, f1: 0.487
# Training results:
# Acc: 0.515, f1: 0.499, loss: 0.697
# Validation results:
# Acc: 0.509, f1: 0.503
# Training results:
# Acc: 0.515, f1: 0.486, loss: 0.697
# Validation results:
# Acc: 0.519, f1: 0.493
# Training results:
# Acc: 0.514, f1: 0.492, loss: 0.697
# Validation results:
# Acc: 0.496, f1: 0.463
# Training results:
# Acc: 0.521, f1: 0.504, loss: 0.697
# Validation results:
# Acc: 0.509, f1: 0.503
# Training results:
# Acc: 0.523, f1: 0.507, loss: 0.697
# Validation results:
# Acc: 0.451, f1: 0.457
# Training results:
# Acc: 0.502, f1: 0.471, loss: 0.697
# Validation results:
# Acc: 0.556, f1: 0.531
# Training results:
# Acc: 0.514, f1: 0.494, loss: 0.697
# Validation results:
# Acc: 0.488, f1: 0.470
# Training results:
# Acc: 0.497, f1: 0.466, loss: 0.697
# Validation results:
# Acc: 0.495, f1: 0.432
# Training results:
# Acc: 0.507, f1: 0.486, loss: 0.697
# Validation results:
# Acc: 0.463, f1: 0.456
# Training results:
# Acc: 0.509, f1: 0.493, loss: 0.697
# Validation results:
# Acc: 0.512, f1: 0.490
# Training results:
# Acc: 0.510, f1: 0.497, loss: 0.697
# Validation results:
# Acc: 0.492, f1: 0.474
# Training results:
# Acc: 0.516, f1: 0.503, loss: 0.697
# Validation results:
# Acc: 0.505, f1: 0.488
# Training results:
# Acc: 0.522, f1: 0.506, loss: 0.697
# Validation results:
# Acc: 0.495, f1: 0.473
# Training results:
# Acc: 0.506, f1: 0.491, loss: 0.697
# Validation results:
# Acc: 0.495, f1: 0.481
# Training results:
# Acc: 0.515, f1: 0.492, loss: 0.697
# Validation results:
# Acc: 0.528, f1: 0.478
# Training results:
# Acc: 0.510, f1: 0.495, loss: 0.697
# Validation results:
# Acc: 0.475, f1: 0.454
# Training results:
# Acc: 0.502, f1: 0.486, loss: 0.696
# Validation results:
# Acc: 0.537, f1: 0.514
# Training results:
# Acc: 0.517, f1: 0.503, loss: 0.697
# Validation results:
# Acc: 0.520, f1: 0.515
# Training results:
# Acc: 0.522, f1: 0.503, loss: 0.697
# Validation results:
# Acc: 0.520, f1: 0.505
# Training results:
# Acc: 0.514, f1: 0.502, loss: 0.697
# Validation results:
# Acc: 0.511, f1: 0.497
# Training results:
# Acc: 0.518, f1: 0.498, loss: 0.697
# Validation results:
# Acc: 0.485, f1: 0.480
# Training results:
# Acc: 0.514, f1: 0.498, loss: 0.697
# Validation results:
# Acc: 0.491, f1: 0.485
# Training results:
# Acc: 0.519, f1: 0.506, loss: 0.697
# Validation results:
# Acc: 0.543, f1: 0.526
# Training results:
# Acc: 0.518, f1: 0.509, loss: 0.697
# Validation results:
# Acc: 0.556, f1: 0.550
# Training results:
# Acc: 0.512, f1: 0.499, loss: 0.697
# Validation results:
# Acc: 0.495, f1: 0.488
# Training results:
# Acc: 0.516, f1: 0.503, loss: 0.698
# Validation results:
# Acc: 0.550, f1: 0.535
# Training results:
# Acc: 0.508, f1: 0.498, loss: 0.697
# Validation results:
# Acc: 0.478, f1: 0.446
# Training results:
# Acc: 0.509, f1: 0.494, loss: 0.697
# Validation results:
# Acc: 0.467, f1: 0.468
# Training results:
# Acc: 0.500, f1: 0.487, loss: 0.697
# Validation results:
# Acc: 0.468, f1: 0.449
# Training results:
# Acc: 0.508, f1: 0.497, loss: 0.697
# Validation results:
# Acc: 0.530, f1: 0.504
# Training results:
# Acc: 0.517, f1: 0.500, loss: 0.697
# Validation results:
# Acc: 0.503, f1: 0.492
# Training results:
# Acc: 0.521, f1: 0.510, loss: 0.697
# Validation results:
# Acc: 0.513, f1: 0.491
# Training results:
# Acc: 0.510, f1: 0.496, loss: 0.697
# Validation results:
# Acc: 0.512, f1: 0.499
# Training results:
# Acc: 0.517, f1: 0.500, loss: 0.697
# Validation results:
# Acc: 0.474, f1: 0.466
# Training results:
# Acc: 0.517, f1: 0.502, loss: 0.697
# Validation results:
# Acc: 0.513, f1: 0.502
# Training results:
# Acc: 0.511, f1: 0.502, loss: 0.697
# Validation results:
# Acc: 0.481, f1: 0.445
# Training results:
# Acc: 0.513, f1: 0.496, loss: 0.697
# Validation results:
# Acc: 0.519, f1: 0.480
# Training results:
# Acc: 0.516, f1: 0.492, loss: 0.696
# Validation results:
# Acc: 0.471, f1: 0.442
# Training results:
# Acc: 0.509, f1: 0.497, loss: 0.697
# Validation results:
# Acc: 0.512, f1: 0.497
# Training results:
# Acc: 0.515, f1: 0.499, loss: 0.696
# Validation results:
# Acc: 0.526, f1: 0.517
# Training results:
# Acc: 0.510, f1: 0.494, loss: 0.696
# Validation results:
# Acc: 0.474, f1: 0.473
# Training results:
# Acc: 0.513, f1: 0.502, loss: 0.697
# Validation results:
# Acc: 0.494, f1: 0.483
# Training results:
# Acc: 0.516, f1: 0.503, loss: 0.697
# Validation results:
# Acc: 0.578, f1: 0.561
# Training results:
# Acc: 0.523, f1: 0.509, loss: 0.697
# Validation results:
# Acc: 0.553, f1: 0.532
# Training results:
# Acc: 0.523, f1: 0.508, loss: 0.697
# Validation results:
# Acc: 0.504, f1: 0.494
# Training results:
# Acc: 0.516, f1: 0.505, loss: 0.697
# Validation results:
# Acc: 0.488, f1: 0.477
# Training results:
# Acc: 0.516, f1: 0.500, loss: 0.697
# Validation results:
# Acc: 0.522, f1: 0.508
# Training results:
# Acc: 0.517, f1: 0.503, loss: 0.696
# Validation results:
# Acc: 0.449, f1: 0.432
# Training results:
# Acc: 0.524, f1: 0.514, loss: 0.697
# Validation results:
# Acc: 0.498, f1: 0.486
# Training results:
# Acc: 0.513, f1: 0.500, loss: 0.696
# Validation results:
# Acc: 0.481, f1: 0.447
# Training results:
# Acc: 0.526, f1: 0.516, loss: 0.697
# Validation results:
# Acc: 0.533, f1: 0.527
# Training results:
# Acc: 0.522, f1: 0.512, loss: 0.697
# Validation results:
# Acc: 0.464, f1: 0.452
# Training results:
# Acc: 0.520, f1: 0.506, loss: 0.697
# Validation results:
# Acc: 0.492, f1: 0.478
# Training results:
# Acc: 0.519, f1: 0.507, loss: 0.697
# Validation results:
# Acc: 0.535, f1: 0.519
# Training results:
# Acc: 0.521, f1: 0.511, loss: 0.696
# Validation results:
# Acc: 0.516, f1: 0.508
# Training results:
# Acc: 0.524, f1: 0.513, loss: 0.697
# Validation results:
# Acc: 0.485, f1: 0.478
# Training results:
# Acc: 0.532, f1: 0.522, loss: 0.696
# Validation results:
# Acc: 0.461, f1: 0.449
# Training results:
# Acc: 0.516, f1: 0.502, loss: 0.696
# Validation results:
# Acc: 0.512, f1: 0.507
# Training results:
# Acc: 0.509, f1: 0.498, loss: 0.697
# Validation results:
# Acc: 0.491, f1: 0.479
# Training results:
# Acc: 0.521, f1: 0.508, loss: 0.696
# Validation results:
# Acc: 0.516, f1: 0.490
# Training results:
# Acc: 0.519, f1: 0.507, loss: 0.697
# Validation results:
# Acc: 0.509, f1: 0.496

# %% [markdown]
# ## Testing the Model

# %% [markdown]
# ### Load Test Dataset

# %%
test_df = pd.read_csv(f"{data_path}/test.csv")
test_docs = test_df['input'][:test_docs_used].to_list()
test_y = test_df['label'][:test_docs_used].apply(lambda label: [0, 1] if label == 1 else [1, 0]).to_list()

test_X = tokenizer(test_docs, max_length=512, truncation='longest_first', return_tensors="pt", padding="max_length")

# %% [markdown]
# ### Evaluate on Test Predictions

# %%
test_X.to(device)
model = torch.load(path)
model.eval()
with torch.no_grad():
    predictions = model(tokens=test_X['input_ids'], attention_mask=test_X['attention_mask'])
    acc_test, f1_test = eval_prediction(torch.tensor(test_y), predictions)

print("Testing results: ")
print("Acc: {:.3f}, f1: {:.3f}".format(acc_test, f1_test))
# Out:
# Testing results:
# Acc: 0.493, f1: 0.481
